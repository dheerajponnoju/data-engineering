# %% [raw]
# 1. Find the Count of Orders Per Customer
# Aggregation, GroupBy
# Description
# This task finds the count of orders placed by each customer.
# Schema
# root
#   |-- customer_id: integer (nullable = true)
#   |-- order_id: integer (nullable = true)
#   |-- order_date: date (nullable = true)
# Input
# +------------+---------+------------+
# | customer_id| order_id| order_date |
# +------------+---------+------------+
# |     101    |   1     | 2023-01-01 |
# |     102    |   2     | 2023-01-03 |
# |     101    |   3     | 2023-01-05 |
# |     103    |   4     | 2023-01-07 |
# |     102    |   5     | 2023-01-09 |
# +------------+---------+------------+
# Output
#  +------------+-----------------+
# | customer_id| order_count     |
# +------------+-----------------+
# |     101    |       2         |
# |     102    |       2         |
# |     103    |       1         |
# +------------+-----------------+

# %%
import os
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, IntegerType, DateType
from pyspark.sql.functions import count, col

# %%
problem_name = os.path.abspath(".").split("/")[-1]

# %%
spark = SparkSession.builder.appName(problem_name).getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/30 22:05:45 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
customers_schema = StructType([
    StructField("customer_id", IntegerType(), True),
    StructField("order_id", IntegerType(), True),
    StructField("order_date", DateType(), True)
])

# %%
customers = spark.read\
.option("header", "true")\
.format("csv")\
.schema(customers_schema)\
.load("files/customers.txt")

# %%
result_df = customers\
.groupBy("customer_id").agg(count("order_id").alias("orders_count"))

# %%
result_df.show(truncate=False)
# Out:
# [Stage 0:>                                                          (0 + 1) / 1]
# +-----------+------------+
# |customer_id|orders_count|
# +-----------+------------+
# |101        |2           |
# |103        |1           |
# |102        |2           |
# +-----------+------------+

# %%
customers.createOrReplaceTempView("customers")

# %%
spark.sql(
    """
    select customer_id, count(order_id) as orders_count
    from customers
    group by customer_id
    """
).show(truncate=False)
# Out:
# +-----------+------------+
# |customer_id|orders_count|
# +-----------+------------+
# |101        |2           |
# |103        |1           |
# |102        |2           |
# +-----------+------------+

# %%
spark.stop()
