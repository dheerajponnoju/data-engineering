# %% [raw]
# Simplifying Date Formats
# Regex
# Description
# You are given a PySpark DataFrame containing information about individuals, including their names, IDs, and date of birth (DOB). However, the DOB data might be inconsistent, with some dates formatted as "YYYY-MM-DD" while others are in the "DD-MM-YYYY" format. Your task is to create a function that takes this DataFrame as input and corrects the format of the DOB column. Specifically, the function should identify any dates in the "DD-MM-YYYY" format and convert them to "YYYY-MM-DD". Additionally, the function should add a new column indicating whether the DOB was corrected or if it was already in the correct format.
# Schema
# Input
# +-----+---+----------+
#  | Name| ID|       DOB|
#  +-----+---+----------+
#  | John|  1|1990-05-25|
#  |Alice|  2|15-08-1985|
#  |  Bob|  3|2001-11-10|
#  | Mary|  4|12-07-1978|
#  +-----+---+----------+
# Output
# +-----+---+------------+-------------------+
#  | Name| ID|         DOB|   Correction_Status|
#  +-----+---+------------+-------------------+
#  | John|  1|  1990-05-25| No change required|
#  |Alice|  2|  1985-08-15|       DOB corrected|
#  |  Bob|  3|  2001-11-10| No change required|
#  | Mary|  4|  1978-07-12|       DOB corrected|
#  +-----+---+------------+-------------------+

# %%
import os
from pyspark.sql import SparkSession
from pyspark.sql.functions import regexp_extract, col, when, to_date

# %%
problem_name = os.path.basename(os.path.abspath("."))

# %%
spark = SparkSession.builder.appName(problem_name).getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/30 23:50:03 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
df = spark.read\
.option("header", "true")\
.format("csv")\
.load("files/people_data.txt")

# %%
df.show()
# Out:
# +-----+---+----------+
# | Name| ID|       DOB|
# +-----+---+----------+
# | John|  1|1990-05-25|
# |Alice|  2|15-08-1985|
# |  Bob|  3|2001-11-10|
# | Mary|  4|12-07-1978|
# +-----+---+----------+

# %%
result_df = df.withColumn("dbo_yyy", regexp_extract("DOB", "\\d{4}-\\d{2}-\\d{2}", 0))\
.withColumn("dbo_dd", regexp_extract("DOB", "\\d{2}-\\d{2}-\\d{4}", 0))\
.withColumn("Correction_Status", 
           when(col("dbo_yyy").isin("", None), "DOB corrected").otherwise("No change required")
           )\
.withColumn("DOB", 
           when(col("Correction_Status")=="DOB corrected", to_date("DOB", "dd-MM-yyyy"))\
            .otherwise(col("DOB"))
           )\
.select("Name", "ID", "DOB", "Correction_Status")

# %%
result_df.show()
# Out:
# +-----+---+----------+------------------+
# | Name| ID|       DOB| Correction_Status|
# +-----+---+----------+------------------+
# | John|  1|1990-05-25|No change required|
# |Alice|  2|1985-08-15|     DOB corrected|
# |  Bob|  3|2001-11-10|No change required|
# | Mary|  4|1978-07-12|     DOB corrected|
# +-----+---+----------+------------------+

# %%
spark.stop()
