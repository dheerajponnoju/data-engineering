# %% [raw]
# Find Employees Who Are Older Than the Average Age in Their Department
# Window Functions, Aggregation, Data Filtering
# Description
# This query uses window functions to calculate the average age in each department and filters out employees who are older than the average age within their department.
# Schema
# root
#   |-- emp_id: integer (nullable = true)
#   |-- department_id: integer (nullable = true)
#   |-- age: integer (nullable = true)
#
# root
#   |-- department_id: integer (nullable = true)
#   |-- department_name: string (nullable = true)
# Input
# +-------+--------------+-----+
# | emp_id| department_id| age |
# +-------+--------------+-----+
# |   1   |     101      | 30  |
# |   2   |     102      | 40  |
# |   3   |     101      | 25  |
# |   4   |     103      | 35  |
# |   5   |     102      | 50  |
# |   6   |     101      | 55  |
# |   7   |     101      | 45  |
# |   8   |     102      | 30  |
# |   9   |     103      | 60  |
# |   10  |     101      | 28  |
# +-------+--------------+-----+
# Output
#  +-------+--------------+-----+-------------------+
# | emp_id| department_id| age | department_name   |
# +-------+--------------+-----+-------------------+
# |   1   |     101      | 30  | HR                |
# |   7   |     101      | 45  | HR                |
# +-------+--------------+-----+-------------------+

# %%
from os.path import basename, abspath
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, avg
from pyspark.sql.window import Window

# %%
problem_name = basename(abspath("."))

# %%
spark = SparkSession.builder.appName(problem_name).getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/06 01:44:37 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
employees = spark.read\
    .option("header", "true")\
    .option("inferSchema", "true")\
    .format("csv")\
    .load("files/employees.txt")

# %%
departments = spark.read\
    .option("header", "true")\
    .option("inferSchema", "true")\
    .format("csv")\
    .load("files/departments.txt")

# %%
employees.createOrReplaceTempView("employees")

# %%
departments.createOrReplaceTempView("departments")

# %%
employees.show()
# Out:
# +------+-------------+---+
# |emp_id|department_id|age|
# +------+-------------+---+
# |     1|          101| 30|
# |     2|          102| 40|
# |     3|          101| 25|
# |     4|          103| 35|
# |     5|          102| 50|
# |     6|          101| 55|
# |     7|          101| 45|
# |     8|          102| 30|
# |     9|          103| 60|
# |    10|          101| 28|
# +------+-------------+---+

# %%
departments.show()
# Out:
# +-------------+---------------+
# |department_id|department_name|
# +-------------+---------------+
# |          101|             HR|
# |          102|             IT|
# |          103|        Finance|
# +-------------+---------------+

# %%
result = employees.withColumn("average_age", 
                     avg(col("age")).over(Window.partitionBy("department_id"))
                    )\
    .filter(col("age")>col("average_age"))\
    .join(departments.alias("d"), on = "department_id", how = "inner")\
    .select("emp_id", "d.department_id", "age", "d.department_name")

# %%
result.show()
# Out:
# +------+-------------+---+---------------+
# |emp_id|department_id|age|department_name|
# +------+-------------+---+---------------+
# |     6|          101| 55|             HR|
# |     7|          101| 45|             HR|
# |     5|          102| 50|             IT|
# |     9|          103| 60|        Finance|
# +------+-------------+---+---------------+

# %%
spark.sql(
    """
    with cte as (
    select e.emp_id, d.department_id, e.age, avg(age) over(partition by d.department_id) as average_age,
    d.department_name
    from employees e join departments d on e.department_id = d.department_id
    )

    select emp_id, department_id, age, department_name
    from cte 
    where age>average_age
    """
).show()
# Out:
# +------+-------------+---+---------------+
# |emp_id|department_id|age|department_name|
# +------+-------------+---+---------------+
# |     6|          101| 55|             HR|
# |     7|          101| 45|             HR|
# |     5|          102| 50|             IT|
# |     9|          103| 60|        Finance|
# +------+-------------+---+---------------+

# %%
spark.stop()
