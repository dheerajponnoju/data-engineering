# %% [raw]
# Find the Total Sales for Each Category
# Aggregation, GroupBy
# Description
# This task involves finding the total sales for each category using the sum() aggregation function.
# Schema
# root
#   |-- category: string (nullable = true)
#   |-- total_price: double (nullable = true)
# Input
# +---------+-----------+
# | category| total_price|
# +---------+-----------+
# | Food    | 5000      |
# | Electronics | 20000  |
# | Food    | 3000      |
# | Clothing| 10000     |
# | Electronics | 15000  |
# | Food    | 2500      |
# +---------+-----------+
# Output
#  +---------+-----------+
# | category| total_sales|
# +---------+-----------+
# | Food    | 10500     |
# | Electronics | 35000 |
# | Clothing| 10000    |
# +---------+-----------+

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, sum as Sum
from os.path import basename, abspath

# %%
problem_name = basename(abspath("."))

# %%
spark = SparkSession.builder.appName(problem_name).getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/05 23:24:11 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
sales = spark.read\
    .option("header", "true")\
    .option("inferSchema", "true")\
    .format("csv")\
    .load("files/sales.txt")

# %%
sales.show()
# Out:
# +-----------+-----------+
# |   category|total_price|
# +-----------+-----------+
# |       Food|       5000|
# |Electronics|      20000|
# |       Food|       3000|
# |   Clothing|      10000|
# |Electronics|      15000|
# |       Food|       2500|
# +-----------+-----------+

# %%
sales.createOrReplaceTempView("sales")

# %%
result = sales.groupBy(col("category")).agg(Sum(col("total_price")).alias("total_sales"))

# %%
result.show()
# Out:
# +-----------+-----------+
# |   category|total_sales|
# +-----------+-----------+
# |       Food|      10500|
# |Electronics|      35000|
# |   Clothing|      10000|
# +-----------+-----------+

# %%
spark.sql(
    """
    select category, sum(total_price) as total_sales
    from sales
    group by category
    """
).show()
# Out:
# +-----------+-----------+
# |   category|total_sales|
# +-----------+-----------+
# |       Food|      10500|
# |Electronics|      35000|
# |   Clothing|      10000|
# +-----------+-----------+

# %%
spark.stop()
