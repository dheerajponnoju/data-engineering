// %%
spark
// Out:
// Intitializing Scala interpreter ...
// Spark Web UI available at http://192.168.1.9:4040
// SparkContext available as 'sc' (version = 3.4.1, master = local[*], app id = local-1771439922766)
// SparkSession available as 'spark'
// res0: org.apache.spark.sql.SparkSession = org.apache.spark.sql.SparkSession@2f08a566
