# %% [raw]
# Averaging Grades Across Subjects from JSON Data
# Description
# Given JSON data detailing students' grades in various subjects, the task is to derive the average score per subject. This involves parsing the JSON structure to extract individual student grades, then aggregating scores for each subject to compute their averages. The expected output format would likely present each subject alongside its corresponding average score, providing a clear overview of academic performance across subjects.
# Schema
# Input
# {   "student_id": 1,  "name": "Alice",
#    "grades": [
#  	{"subject": "Math", "score": 85},
#  	{"subject": "Science", "score": 90},
#  	{"subject": "English", "score": 80}
#    ] }
#  {   "student_id": 2,   "name": "Bob",
#    "grades": [
#  	{"subject": "Math", "score": 75},
#  	{"subject": "Science", "score": 80},
#  	{"subject": "English", "score": 85}
#    ] }
# Output
# +-------+-----------------+
#  |subject|     avg(score)  |
#  +-------+-----------------+
#  | Math  |     80.0         |
#  |Science|     85.0         |
#  |English|     82.5         |
#  +-------+-----------------+

# %%
import os
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, explode, avg

# %%
problem_name = os.path.basename(os.path.abspath("."))

# %%
spark = SparkSession.builder.appName(problem_name).getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/30 23:24:09 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
grades = spark.read\
.option("multiLine", "true")\
.format("json")\
.load("files/grades.json")

# %%
grades.show()
# Out:
# +--------------------+-----+----------+
# |              grades| name|student_id|
# +--------------------+-----+----------+
# |[{85, Math}, {90,...|Alice|         1|
# |[{75, Math}, {80,...|  Bob|         2|
# +--------------------+-----+----------+

# %%
result_df = grades.withColumn("exploded_grades", explode("grades"))\
.select(col("exploded_grades.score").alias("score"), col("exploded_grades.subject").alias("subject"))\
.groupBy("subject").agg(avg("score"))

# %%
result_df.show()
# Out:
# +-------+----------+
# |subject|avg(score)|
# +-------+----------+
# |Science|      85.0|
# |   Math|      80.0|
# |English|      82.5|
# +-------+----------+

# %%
spark.stop()
