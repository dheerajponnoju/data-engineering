# %% [raw]
# Find Employees Who Have Worked More Than 5 Years
# Filtering, Date Functions
# Description
# This task filters employees who have been with the company for more than 5 years.
# Schema
# root
#   |-- emp_id: integer (nullable = true)
#   |-- name: string (nullable = true)
#   |-- join_date: date (nullable = true)
# Input
# +-------+----------+------------+
# | emp_id| name     | join_date  |
# +-------+----------+------------+
# |   1   | John     | 2015-03-12 |
# |   2   | Alice    | 2018-05-20 |
# |   3   | Bob      | 2010-06-14 |
# |   4   | Carol    | 2019-07-08 |
# |   5   | Dave     | 2013-02-25 |
# +-------+----------+------------+
# Output
#  +-------+--------+------------+
# | emp_id| name   | join_date  |
# +-------+--------+------------+
# |   1   | John   | 2015-03-12 |
# |   3   | Bob    | 2010-06-14 |
# |   5   | Dave   | 2013-02-25 |
# +-------+--------+------------+

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, datediff, lit
from os.path import basename, abspath

# %%
problem_name = basename(abspath("."))

# %%
spark = SparkSession.builder.appName(problem_name).getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/06 00:33:10 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
employees = spark.read\
    .option("header", "true")\
    .option("inferSchema", "true")\
    .format("csv")\
    .load("files/employees.txt")

# %%
employees.show()
# Out:
# +------+-----+----------+
# |emp_id| name| join_date|
# +------+-----+----------+
# |     1| John|2015-03-12|
# |     2|Alice|2018-05-20|
# |     3|  Bob|2010-06-14|
# |     4|Carol|2019-07-08|
# |     5| Dave|2013-02-25|
# +------+-----+----------+

# %%
employees.createOrReplaceTempView("employees")

# %%
result = employees\
    .withColumn("date_diff", datediff(lit("2020-05-01").cast("date"), col("join_date"))/365)\
    .filter(col("date_diff")>5)\
    .select(employees.columns)

# %%
result.show()
# Out:
# +------+----+----------+
# |emp_id|name| join_date|
# +------+----+----------+
# |     1|John|2015-03-12|
# |     3| Bob|2010-06-14|
# |     5|Dave|2013-02-25|
# +------+----+----------+

# %%
spark.sql(
    """
    select *
    from employees
    where datediff(cast('2020-05-01' as date), join_date)/365 > 5
    """
).show()
# Out:
# +------+----+----------+
# |emp_id|name| join_date|
# +------+----+----------+
# |     1|John|2015-03-12|
# |     3| Bob|2010-06-14|
# |     5|Dave|2013-02-25|
# +------+----+----------+

# %%
spark.stop()
